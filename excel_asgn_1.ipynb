# %% [markdown]
# # What is Excel? Why do we use Excel?
#
# excel is software comes with microsoft office pakage.
# excel is in format of sheet with large number of columns and rows which forms a cells.
# excel is used to visualize and analyze the data.
# it can order, sort, store random data in spreadsheet.
# it can be used to perform data entry, data storage, calculation (basic, advanced),
# visualize data as form of pivot table, graphs, etc.

# %% [markdown]
# # List all the versions of Microsoft excel. Compare excel software provided from multiple vendors.
#
# windows excel 2003, 2007, 2010, 2013, 2019, office 365
# there are some changes in every version considering various fitures, dashboard updates, data connection and sharing options etc.\n
#
# different vendors providing excel are microsoft, google sheets, WPS, ZOHO, Libre.\n
#
# the google sheet lacks with fitures of the excel but easy to acess. WPS is free version available on PC and mobile, lack i lot of features. ZOHO comes with smoother interface with pivot table and charts. libre is open sourse free to use application with some of the features from the excel.

# %% [markdown]
# # How to create bar charts in excel, demonstrated with practical examples.
#
# it is very easy to create a bar chart in the excel,\n
# select the two columns containing the data to be plotted. \n
# go to insert then to chart select eighter recommended chart or the custom one\n
# graph will be generated.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Create an analytics dashboard in python and present your findings.
#
# it can be done using a matplot library along with dash.

# %% [markdown]
# # How to connect Excel with the databases.
#
# 1> go to function ribbon,
#
# 2> Data,
#
# 3> Get data,
#
# 4> from database,
#
# 5> then from mutiple option you can choose database
#
# 6> server, database, done.
