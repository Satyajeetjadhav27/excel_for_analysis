# %% [markdown]
# # What is macro? Create a macro to store product detail.
#
# the macros are the automatic functions used to automate the manual task.
#
# for example, if we record a macro, and use that macro it will repeat that task.
#
# here product detail macro has been created.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Explain Excel formatting
#
# the excel formating is done to visualize the data clearly.
#
# there are various excel formatting options.
#
# following are some formatting options:-
#
# 1. adding border
# 2. format painter
# 3. format cell: it contains custom formatting and some prior defined formats for currency, number, date, time, text,etc.
# 4. conditional formatting- make the data more visually interactive and attractive.

# %% [markdown]
# # Perform data analysis using Excel. List various functions available to perform data analysis in excel.
#
#
# 1. countblanks- it is used to give the count of the blanks
# 2. rank - it will give the ranking based on the column values
# 3. average- returns average
# 4. sumif/s- it will sum the data based on the some conditions that are mensioned
# 5. vlookup- it is used to look a certain data in the sample
# 6. max, min, etc.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # List down excel functions and their examples
#
#
# 1. count - it is used to count args
# 2. counta- it will count number of values in args
# 3. countblank
# 4. countif/s
# 5. sumif/s
# 6. averageif/s
# 7. squareroot- sqrt
# 8. mod
# 9. product
# 10. factorail- fact
# 11. find
# 12. replace
# 13. substitute
# 14. roundof
# 15. isblank
# 16. isnumber
# 17. iserr
# 18. vlookup
# 19. hlookup
# 19. match
# 20. index
# 21. if
# 22. mean
# 23. meadian
# 24. mode
# 25. stddev
# 26. variance - var

# %% [markdown]
# # How to add annotations to a cell in Excel.
#
#
#  right click on cell, go to comment , add a comment
#
#  or go to review tab, add comment, and you can add comment
