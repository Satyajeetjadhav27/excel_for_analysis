# %% [markdown]
# # What do you mean by “Relative Cell Referencing” in MS Excel and “Absolute cell referencing”?
#
#
# in case of macro,
#
# if we use "use relative references" before starting "record macro"
#
# then it will record it as relative or else it record as absolute cell reffering.

# %% [markdown]
# # How to secure an excel workbook, demonstrate it with an example.
#
#
# 1. go to review section
# 2. go to protect workbook - to protect overall workbook, by setting up a password
# 3. go to protect sheeet- here list of sheet is there select which sheet you want to protect and set the password

# %% [markdown]
# # Explain the pivot tables and their implementations.
#
#
# the pivot table is short table with help of this the data can be visualised easily
#
# the different filter, sorting can be applied
#
# these can be used to show a sub data in dashboard
#
# the following figure shows the use of pivot table
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Explain lookup in excel with suitable examples.
#
# when need to lookup a data in same row or column and spacifying the location from current cell, the data can be viewed from the table.
#
# there are two type lookup - hlookup (row) and vlookup (column)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # What is Data validation, and how to implement it in Excel?
#
#
# data validation means it will accept only certain type of the data as a input
#
# eg. anyvalue, decimal, whole number, date, time, text_length
#
# 1. go to data
# 2. data tool
# 3. data validaation
# 4. select a cell to be validated
# 5. select condition and range and ok
